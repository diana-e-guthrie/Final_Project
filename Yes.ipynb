# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('excelview.csv')

# %%
df2 = df.dropna()
df2
# Out:
#      Unnamed: 0                       Address  Beds_Min  Beds_Max  Baths_Min  \
# 1             1               2190 E 11th Ave         0         3        1.0
# 5             5               2315 E 12th Ave         1         2        1.0
# 11           11           925-995 Humboldt St         1         2        1.0
# 13           13         1269 Columbine St # 6         1         1        1.0
# 14           14             1262 Columbine St         1         1        1.0
# ..          ...                           ...       ...       ...        ...
# 187         187  4750 E Cherry Creek South Dr         1         3        1.0
# 188         188           818-848 S Dexter St         1         2        1.0
# 191         191               878 S Dexter St         0         2        1.0
# 193         193                3331 N Race St         2         2        1.5
# 198         198               5151 E 28th Ave         2         3        4.0
#
#      Baths_Max  Sqft_Min  Sqft_Max        Lat         Lon  Distance  Rent  \
# 1          2.0     516.0    1331.0  39.733230 -104.961560  0.590335  1638
# 5          1.0     599.0     828.0  39.735298 -104.959447  0.805370  1300
# 11         1.0     488.0     755.0  39.730660 -104.969870  0.895747  1199
# 13         1.0     500.0     500.0  39.736436 -104.957763  0.949487  1225
# 14         1.0     650.0     650.0  39.736365 -104.957119  0.954248  1100
# ..         ...       ...       ...        ...         ...       ...   ...
# 187        2.0     687.0    1429.0  39.702639 -104.932119  3.697704  1300
# 188        2.0     580.0     985.0  39.701790 -104.932290  3.761213  1145
# 191        2.0     500.0    1080.0  39.700560 -104.932380  3.863796  1007
# 193        1.5     950.0     950.0  39.763875 -104.963555  3.994682  2195
# 198        4.0    1619.0    2010.0  39.756756 -104.927923  4.205736  2800
#
#      Rent_max              Neighborhood                      City  Walk Score  \
# 1        3076             Cheesman Park             Cheesman Park        85.0
# 5        1600             Congress Park             Congress Park        80.0
# 11       1619             Cheesman Park             Cheesman Park        85.0
# 13       1225             Congress Park             Congress Park        80.0
# 14       1100             Congress Park             Congress Park        80.0
# ..        ...                       ...                       ...         ...
# 187      2585  Washington Virginia Vale  Washington Virginia Vale        67.0
# 188      1460  Washington Virginia Vale  Washington Virginia Vale        67.0
# 191      1041  Washington Virginia Vale  Washington Virginia Vale        67.0
# 193      2195                      Cole                      Cole        82.0
# 198      3200                 Park Hill                 Park Hill        60.0
#
#      Transit Score  Bike Score  Population
# 1             53.0        90.0      7984.0
# 5             51.0        88.0     10239.0
# 11            53.0        90.0      7984.0
# 13            51.0        88.0     10239.0
# 14            51.0        88.0     10239.0
# ..             ...         ...         ...
# 187           44.0        77.0     12838.0
# 188           44.0        77.0     12838.0
# 191           44.0        77.0     12838.0
# 193           54.0        92.0      4646.0
# 198           47.0        80.0     25806.0
#
# [72 rows x 19 columns]

# %%
len(df2)
# Out:
# 72

# %%
foam = df2[["Rent", "Beds_Max","Baths_Min","Sqft_Min","Sqft_Max", "Walk Score", "Transit Score", "Bike Score"]]
foam = foam.dropna()
foam.head()
# Out:
#     Rent  Beds_Max  Baths_Min  Sqft_Min  Sqft_Max  Walk Score  Transit Score  \
# 1   1638         3        1.0     516.0    1331.0        85.0           53.0
# 5   1300         2        1.0     599.0     828.0        80.0           51.0
# 11  1199         2        1.0     488.0     755.0        85.0           53.0
# 13  1225         1        1.0     500.0     500.0        80.0           51.0
# 14  1100         1        1.0     650.0     650.0        80.0           51.0
#
#     Bike Score
# 1         90.0
# 5         88.0
# 11        90.0
# 13        88.0
# 14        88.0

# %%
X = foam[["Beds_Max","Baths_Min","Sqft_Min","Sqft_Max", "Walk Score", "Transit Score", "Bike Score"]]
y = foam["Rent"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (72, 7) (72, 1)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
# Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)


### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.9026730772812063
# Testing Score: 0.7031737850530357

# %%
# Plot the Residuals for the Training and Testing data
import matplotlib.pyplot as plt
### BEGIN SOLUTION
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X_test
# Out:
#      Beds_Max  Baths_Min  Sqft_Min  Sqft_Max  Walk Score  Transit Score  \
# 14          1        1.0     650.0     650.0        80.0           51.0
# 169         3        1.0    1800.0    1800.0        85.0           55.0
# 30          2        1.0     500.0     700.0        85.0           53.0
# 1           3        1.0     516.0    1331.0        85.0           53.0
# 63          1        1.0     753.0     753.0        93.0           66.0
# 127         2        1.0     800.0     800.0        85.0           55.0
# 22          2        2.0    1050.0    1050.0        85.0           53.0
# 87          2        1.0     450.0     800.0        85.0           55.0
# 24          2        1.0    1200.0    1200.0        80.0           51.0
# 139         3        1.0     538.0    1467.0        71.0           48.0
# 122         2        1.0     560.0    1796.0        85.0           55.0
# 81          1        1.0     600.0     600.0        85.0           55.0
# 20          2        1.0     860.0     860.0        80.0           51.0
# 120         2        1.0     519.0    1356.0        71.0           48.0
# 15          2        1.0     641.0    1047.0        85.0           53.0
# 36          2        1.0     600.0     798.0        85.0           53.0
# 152         3        1.0     766.0    2697.0        64.0           42.0
# 124         0        1.0     500.0     500.0        71.0           48.0
#
#      Bike Score
# 14         88.0
# 169        95.0
# 30         90.0
# 1          90.0
# 63         96.0
# 127        95.0
# 22         90.0
# 87         95.0
# 24         88.0
# 139        77.0
# 122        95.0
# 81         95.0
# 20         88.0
# 120        77.0
# 15         90.0
# 36         90.0
# 152        84.0
# 124        77.0

# %%
from sklearn.metrics import mean_squared_error, r2_score

input_beds = 2
input_baths = 1
input_sqft_min = 650
input_sqft_max = 650
input_walk = 85
input_transit = 55
input_bike = 95

input_list = [[input_beds, input_baths, input_sqft_min, input_sqft_max, input_walk, input_transit, input_bike]]

#input_list = [["input_beds, input_baths", "input_sqft_min", "input_sqft_max", "input_walk", "input_transit", "input_bike"]]

input_df = pd.DataFrame(input_list, columns =["input_beds", "input_baths", "input_sqft_min", "input_sqft_max", "input_walk", "input_transit", "input_bike"]) 

# Use our model to make predictions
predicted = model.predict(input_df)

# Score the predictions with mse and r2
# mse = mean_squared_error(y_test, predicted)
# r2 = r2_score(y_test, predicted)

# print(f"Mean Squared Error (MSE): {mse}")
# print(f"R-squared (R2 ): {r2}")
print(predicted)
# Out:
# [[1397.40493585]]

# %%
len(X_test)
# Out:
# 18
